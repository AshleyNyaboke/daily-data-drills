# %% [markdown]
# <a href="https://colab.research.google.com/github/AshleyNyaboke/daily-data-drills/blob/main/basic_relshp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/wheat_seeds.csv')
df
# Out:
#       Area  Perimeter  Compactness  Kernel.Length  Kernel.Width  \
# 0    15.26      14.84       0.8710          5.763         3.312
# 1    14.88      14.57       0.8811          5.554         3.333
# 2    14.29      14.09       0.9050          5.291         3.337
# 3    13.84      13.94       0.8955          5.324         3.379
# 4    16.14      14.99       0.9034          5.658         3.562
# ..     ...        ...          ...            ...           ...
# 194  12.19      13.20       0.8783          5.137         2.981
# 195  11.23      12.88       0.8511          5.140         2.795
# 196  13.20      13.66       0.8883          5.236         3.232
# 197  11.84      13.21       0.8521          5.175         2.836
# 198  12.30      13.34       0.8684          5.243         2.974
#
#      Asymmetry.Coeff  Kernel.Groove  Type
# 0              2.221          5.220     1
# 1              1.018          4.956     1
# 2              2.699          4.825     1
# ...

# %%
df.head()
# Out:
#     Area  Perimeter  Compactness  Kernel.Length  Kernel.Width  \
# 0  15.26      14.84       0.8710          5.763         3.312
# 1  14.88      14.57       0.8811          5.554         3.333
# 2  14.29      14.09       0.9050          5.291         3.337
# 3  13.84      13.94       0.8955          5.324         3.379
# 4  16.14      14.99       0.9034          5.658         3.562
#
#    Asymmetry.Coeff  Kernel.Groove  Type
# 0            2.221          5.220     1
# 1            1.018          4.956     1
# 2            2.699          4.825     1
# 3            2.259          4.805     1
# 4            1.355          5.175     1

# %%
df.describe()
# Out:
#              Area   Perimeter  Compactness  Kernel.Length  Kernel.Width  \
# count  199.000000  199.000000   174.000000     199.000000    199.000000
# mean    14.918744   14.595829     0.869909       5.643151      3.265533
# std      2.919976    1.310445     0.023447       0.443593      0.378322
# min     10.590000   12.410000     0.808100       4.899000      2.630000
# 25%     12.330000   13.470000     0.856675       5.267000      2.954500
# 50%     14.430000   14.370000     0.872300       5.541000      3.245000
# 75%     17.455000   15.805000     0.885625       6.002000      3.564500
# max     21.180000   17.250000     0.918300       6.675000      4.033000
#
#        Asymmetry.Coeff  Kernel.Groove        Type
# count       199.000000     199.000000  199.000000
# mean          3.699217       5.420653    1.994975
# std           1.471102       0.492718    0.813382
# min           0.765100       4.519000    1.000000
# 25%           2.570000       5.046000    1.000000
# ...

# %%
df.columns
# Out:
# Index(['Area', 'Perimeter', 'Compactness', 'Kernel.Length', 'Kernel.Width',
#        'Asymmetry.Coeff', 'Kernel.Groove', 'Type'],
#       dtype='object')

# %%
sns.relplot(x = 'Kernel.Length', y = 'Area',hue= 'Type', data = df )

# %%
sns.pairplot(df)

# %%
df.columns
# Out:
# Index(['Area', 'Perimeter', 'Compactness', 'Kernel.Length', 'Kernel.Width',
#        'Asymmetry.Coeff', 'Kernel.Groove', 'Type'],
#       dtype='object')

# %%
sns.relplot(x ='Perimeter', y = 'Area', kind = 'line', data = df )
